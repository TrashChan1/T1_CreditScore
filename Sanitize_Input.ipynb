# %% [markdown]
# # Take in a file and store it as an array of strings

# %%
import os 
import sys 
script_directory = os.getcwd()
print(script_directory)


text_file = open("PhoneBook.txt", "r")
lines = text_file.readlines()
print(len(lines))
# Out:
# /home/trashc/Projects/Jupyter Notebooks
# 9589

# %%
import matplotlib.pyplot as plt
x = [10, 20, 30, 40, 50, 60]
y = [13, 45, 23, 34, 96, 76]
plt.title('Bar Graph')
plt.bar(x, y, color='dodgerblue', width=5)
plt.show()
